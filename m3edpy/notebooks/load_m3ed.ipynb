# %%
import tonic
import requests
import yaml

# %%
dataset_list_url = ("https://raw.githubusercontent.com/"
                    "daniilidis-group/m3ed/main/dataset_list.yaml")

# %%
response = requests.get(dataset_list_url)

# %%
files = yaml.load(response.text, Loader=yaml.FullLoader)

# %%
files
# Out:
# [{'file': 'car_forest_camera_calib_3', 'filetype': 'camera_calib'},
#  {'file': 'car_forest_camera_calib_4', 'filetype': 'camera_calib'},
#  {'file': 'car_forest_camera_calib_5', 'filetype': 'camera_calib'},
#  {'file': 'car_forest_camera_calib_6', 'filetype': 'camera_calib'},
#  {'file': 'car_forest_sand_1',
#   'filetype': 'data',
#   'camera_calib_reference': 'car_forest_camera_calib_5',
#   'imu_calib_reference': 'tower_imu_calib_1',
#   'lidar_calib_reference': 'car_forest_sand_1_T_c_l.npz',
#   'faster_lio_config': 'long_range_ouster64',
#   'depth_scan_aggregation': 40,
#   'is_test_file': False,
#   'internimage_semantics': False,
#   'check_pose_return': {'absolute_position_error': 0.5},
#   'notes': 'This is a driving sequence on an open space of the forest, where the car is driven on a sand path and there is drift on the wheels. The car returns to the original position. See car_forest_sand_2 for a similar sequence.\n'},
#  {'file': 'car_forest_sand_2',
# ...

# %%
for file in files:
    if file['filetype'] == 'data':
        print(file['file'])
# Out:
# car_forest_sand_1
# car_forest_sand_2
# car_forest_tree_tunnel
# car_forest_into_ponds_long
# car_forest_into_ponds_short
# car_urban_day_city_hall
# car_urban_day_horse
# car_urban_day_penno_big_loop
# car_urban_day_penno_small_loop
# car_urban_day_rittenhouse
# car_urban_day_ucity_big_loop
# car_urban_day_ucity_small_loop
# car_urban_day_schuylkill_tunnel
# car_urban_night_city_hall
# car_urban_night_penno_big_loop
# car_urban_night_penno_small_loop
# car_urban_night_penno_small_loop_darker
# car_urban_night_rittenhouse
# car_urban_night_schuylkill_tunnel
# car_urban_night_ucity_big_loop
# car_urban_night_ucity_small_loop
# falcon_forest_road_1
# falcon_forest_road_forest
# falcon_forest_up_down
# falcon_forest_into_forest_4
# falcon_forest_road_3
# falcon_forest_road_2
# falcon_forest_into_forest_1
# falcon_forest_into_forest_2
# falcon_into_forest_3
# falcon_indoor_flight_1
# falcon_indoor_flight_2
# falcon_indoor_flight_3
# falcon_outdoor_day_penno_parking_1
# ...
